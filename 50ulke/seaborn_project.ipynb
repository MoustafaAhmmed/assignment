# %% [markdown]
# # Countries	\ National Income	\ Growth	\ Per person	\ Continent
# ## seaborn project

# %%
import seaborn as sns
import pandas as pd

# %matplotlib inline
sns.set(rc={'figure.figsize': [9, 9]}, font_scale=1.2)

# %%
df = pd.read_csv('50ulke.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %% [markdown]
# ### Removing unvaluable unnamed coulumen

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
df.head()
# Out:
#         Countries  National Income  Growth  Per person      Continent
# 0   United States         20412.87    2.27     62152.0  North America
# 1           China         14092.51    6.86     10088.0           Asia
# 2           Japan          5167.05    1.71     40849.0           Asia
# 3         Germany          4211.64    2.51     50842.0         Europe
# 4  United Kingdom          2936.29    1.79     44177.0         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Countries        50 non-null     object
#  1   National Income  50 non-null     float64
#  2   Growth           50 non-null     float64
#  3   Per person       50 non-null     float64
#  4   Continent        50 non-null     object
# dtypes: float64(3), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#        National Income     Growth    Per person
# count        50.000000  50.000000     50.000000
# mean       1646.348200   3.320400  27696.000000
# std        3448.554429   2.053468  25094.131496
# min         231.570000  -0.740000   1615.000000
# 25%         353.440000   1.795000   6402.000000
# 50%         522.985000   2.880000  14565.500000
# 75%        1504.895000   4.287500  48738.250000
# max       20412.870000   7.810000  86835.000000

# %%
df["Continent"].nunique()
# Out:
# 6

# %% [markdown]
# ###  Checking countries which have the  heighest &the lowest national income

# %%
sns.scatterplot(x='National Income',y="Countries",data=df)

# %%
df.sort_values(by='National Income',ascending=False)[["Countries",'National Income']].head()
# Out:
#         Countries  National Income
# 0   United States         20412.87
# 1           China         14092.51
# 2           Japan          5167.05
# 3         Germany          4211.64
# 4  United Kingdom          2936.29

# %% [markdown]
# ####    highst N_income
#
# United States	20412.87<br/>
# China	14092.51<br/>
# Japan	5167.05<br/>
# Germany	4211.64<br/>
# United Kingdom	2936.29<br/>

# %%
df.sort_values(by='National Income',ascending=False)[["Countries",'National Income']].tail()
# Out:
#          Countries  National Income
# 45  Czech Republic           251.58
# 46        Portugal           248.89
# 47         Romania           245.59
# 48         Vietnam           240.78
# 49            Peru           231.57

# %% [markdown]
# #### lowest N_income
# Czech Republic	251.58<br/>
# Portugal	248.89<br/>
# Romania	245.59<br/>
# Vietnam	240.78<br/>
# Peru	231.57<br/>

# %% [markdown]
# ###  Checking countries which have the  heighest &the lowest  growth

# %%
sns.scatterplot(x='Growth',y="Countries",data=df)

# %% [markdown]
# #### Highest Growth

# %%
df.sort_values(by='Growth',ascending=False)[["Countries",'Growth']].head()
# Out:
#      Countries  Growth
# 31     Ireland    7.81
# 42  Bangladesh    7.14
# 17      Turkey    7.05
# 47     Romania    7.00
# 1        China    6.86

# %% [markdown]
# #### lowest Growth

# %%
df.sort_values(by='Growth',ascending=False)[["Countries",'Growth']].tail()
# Out:
#                Countries  Growth
# 19           Switzerland    1.07
# 8                 Brazil    0.98
# 30               Nigeria    0.82
# 29  United Arab Emirates    0.53
# 18          Saudi Arabia   -0.74

# %% [markdown]
# ### scattered plot for another view

# %%
sns.scatterplot(x="National Income", y="Growth", data=df, hue='Continent');

# %% [markdown]
# >
# > max growth:   Europe<br/>
# > min growth:   Asia<br/>
# > max National income:   North america<br/>
# > min National income:   South america<br/>

# %%
sns.scatterplot(x='Per person',y="Countries",data=df)

# %%
df.sort_values(by="Per person",ascending=False)[["Countries",'Per person']].head()
# Out:
#         Countries  Per person
# 19    Switzerland     86835.0
# 27         Norway     82711.0
# 31        Ireland     80641.0
# 0   United States     62152.0
# 37      Singapore     61767.0

# %%
df.sort_values(by="Per person",ascending=False)[["Countries",'Per person']].tail()
# Out:
#      Countries  Per person
# 6        India      2135.0
# 30     Nigeria      2108.0
# 42  Bangladesh      1734.0
# 21      Poland      1618.0
# 40    Pakistan      1615.0

# %%
sns.distplot(df["Per person"],bins=30)

# %% [markdown]
# >The most income values for per person in Range between 2000 to 20000 . and The maximum value is 86835 and The lowest value is 1615 .

# %% [markdown]
# ### searching for any corr

# %%
sns.pairplot(df)

# %%
sns.lmplot(x='Per person', y='Growth', data=df)

# %% [markdown]
# > very week -negative correlation

# %%
df.corr()
# Out:
#                  National Income    Growth  Per person
# National Income         1.000000  0.008961    0.159121
# Growth                  0.008961  1.000000   -0.252786
# Per person              0.159121 -0.252786    1.000000

# %% [markdown]
# # Report
# This is data for 6 continent which have 50 countries.<br>
# ####    highst N_income
# United States	20412.87<br/>
# China	14092.51<br/>
# Japan	5167.05<br/>
# Germany	4211.64<br/>
# United Kingdom	2936.29<br/>
# #### lowest N_income
# Czech Republic	251.58<br/>
# Portugal	248.89<br/>
# Romania	245.59<br/>
# Vietnam	240.78<br/>
# Peru	231.57<br/>
# #### highest growth
# Ireland	7.81<br/>
# Bangladesh	7.14<br/>
# Turkey	7.05<br/>
# Romania	7.00<br/>
# China	6.86<br/>
# #### lowest growth
# Switzerland	1.07<br/>
# Brazil	0.98<br/>
# Nigeria	0.82<br/>
# United Arab Emirates	0.53<br/>
# Saudi Arabia	-0.74<br/>
# #### highest per person
# Switzerland	86835.0<br/>
# Norway	82711.0<br/>
# Ireland	80641.0<br/>
# United States	62152.0<br/>
# Singapore	61767.0<br/>
# #### lowest Per person
# India	2135.0<br/>
# Nigeria	2108.0<br/>
# Bangladesh	1734.0<br/>
# Poland	1618.0<br/>
# Pakistan	1615.0<br/>

# %%
Countries	National Income	Growth	Per person	Continen

# %%
sns.boxplot(x=df["National Income"])
